# %%
def RectangleArea(a,b):
  if a == 0 or b == 0:
    return 'the area of the retangle is: -1'
  else:
    return f'the area of the retangle is: {a * b} '

# %%
RectangleArea(2,0)
# Out:
# 'the area of the retangle is: -1'
